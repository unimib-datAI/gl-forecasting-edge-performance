# %%
import importlib
import New_data_prep as dp

importlib.reload(dp)
# Out:
# <module 'New_data_prep' from '/Users/kingsley/Documents/TESI/GITHUB_TESI/gl-forecasting-edge-performance/src/New_data_prep.py'>

# %%
VERSION = 'V1'
base_output_folder = "../experiments"
path_to_csvs = "../data/raw/source_domain/"
path_to_csvs_target = "../data/raw/target_domain/"
path_to_networks = "../data/networks"
n = 20
k = 19
seed = 4850
split_seed=42
PATH_TO_SPLITS =  f"../data/splits/{VERSION}/"
PATH_TO_SCALERS =  f'../output/scalers/baselines/{VERSION}/'
node_types = ["LIGHT", "MID", "HEAVY"]

# %%
PATH_TO_AUGMENTED_ROWS = f"../data/augmented_rows/{VERSION}/"

# %%
simulation = 0

# %%
dp.prepare_data(
    base_output_folder,
    path_to_csvs,
    path_to_csvs_target,
    path_to_networks,
    PATH_TO_SPLITS,
    PATH_TO_SCALERS,
    n,
    k,
    seed,
    simulation,
    node_types,
    split_seed
)
# Out:
# /Users/kingsley/Documents/TESI/GITHUB_TESI/gl-forecasting-edge-performance/src/New_data_prep.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#
# /Users/kingsley/Documents/TESI/GITHUB_TESI/gl-forecasting-edge-performance/src/New_data_prep.py:70: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   # Function to assign zero to noise metrics where requests rates are 0
# cpu_usage_function_shasum
# 23887
# ram_usage_function_shasum
# 23430
# medium_latency_function_shasum
# 23610
# cpu_usage_function_curl
# 14017
# ram_usage_function_curl
# 13650
# medium_latency_function_curl
# 13920
# cpu_usage_function_eat_memory
# 4571
# ram_usage_function_eat_memory
# 4501
# medium_latency_function_eat_memory
# 4564
# cpu_usage_node
# 32741
# ram_usage_node
# 32385
# ram_usage_node_percentage
# 32127
# ram_usage_node_perc_theor
# 32385
# overloaded_node
# overloaded_node
# 0.0    89169
# 1.0     9563
# Name: count, dtype: int64
# cpu_usage_function_nmap
# 7319
# ram_usage_function_nmap
# 7245
# medium_latency_function_nmap
# 7301
# cpu_usage_function_env
# 19397
# ram_usage_function_env
# 18812
# medium_latency_function_env
# 19202
# cpu_usage_function_figlet
# 19900
# ram_usage_function_figlet
# 19762
# medium_latency_function_figlet
# 19790
# cpu_usage_function_figlet
# 16476
# ram_usage_function_figlet
# 16403
# medium_latency_function_figlet
# 16250
# cpu_usage_function_shasum
# 16498
# ram_usage_function_shasum
# 16352
# medium_latency_function_shasum
# 16298
# cpu_usage_function_nmap
# 7290
# ram_usage_function_nmap
# 7192
# medium_latency_function_nmap
# 7256
# cpu_usage_node
# 21955
# ram_usage_node
# 21629
# ram_usage_node_percentage
# 22094
# ram_usage_node_perc_theor
# 21629
# overloaded_node
# overloaded_node
# 0    59483
# 1     8090
# Name: count, dtype: int64
# cpu_usage_function_env
# 8297
# ram_usage_function_env
# 8251
# medium_latency_function_env
# 8119
# cpu_usage_function_eat_memory
# 2817
# ram_usage_function_eat_memory
# 2748
# medium_latency_function_eat_memory
# 2756
# cpu_usage_function_curl
# 6781
# ram_usage_function_curl
# 6695
# medium_latency_function_curl
# 6667
# load nodes network
# ...done
# build nodes dataframes
# ...done
# split and save
# processing node 0
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:43.732599
# Start Train/Val Split: 2026-04-16 16:21:43.795160
# Start Oversampling: 2026-04-16 16:21:43.871404
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1380
# After limiting: 460 (removed 920)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                424
# 1.0                 36
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 36, Non-overloaded: 424
# Generating 388 synthetic samples for node_type 0
# Generated 388 samples for node_type 0
#
#  Total synthetic samples generated: 388
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1272, overloaded=1: 108
# Need to add 1164 more rows for overloaded=1
# Augmented rows available for this node_type=0: 388
# Repeating augmented rows 3 times
# Rows actually added: 1164
# After augmentation → overloaded=0: 1272, overloaded=1: 1272
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1272
# 1.0                1272
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1272  1272
#
# Final node_type distribution:
# node_type
# 0    2544
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 848
# Unique feature combinations for 0       : 424
# Unique feature combinations for 1       : 424
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:43.914837
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2544        346         432
# ## Data Leakage Check:
# Train Samples: 2544
# Val Samples: 346
# Test Samples: 432
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2544, 7)
#   - Regression targets shape: (2544, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2544, 7)
#   - X_val shape: (346, 7)
#   - X_test shape: (432, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:43.936897
# processing node 4
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:44.221164
# Start Train/Val Split: 2026-04-16 16:21:44.282396
# Start Oversampling: 2026-04-16 16:21:44.359355
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1378
# After limiting: 460 (removed 918)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                426
# 1.0                 34
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 34, Non-overloaded: 426
# Generating 392 synthetic samples for node_type 0
# Generated 392 samples for node_type 0
#
#  Total synthetic samples generated: 392
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1276, overloaded=1: 102
# Need to add 1174 more rows for overloaded=1
# Augmented rows available for this node_type=0: 392
# Repeating augmented rows 3 times
# Rows actually added: 1174
# After augmentation → overloaded=0: 1276, overloaded=1: 1276
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1276
# 1.0                1276
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1276  1276
#
# Final node_type distribution:
# node_type
# 0    2552
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 852
# Unique feature combinations for 0       : 426
# Unique feature combinations for 1       : 426
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:44.396163
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2552        348         432
# ## Data Leakage Check:
# Train Samples: 2552
# Val Samples: 348
# Test Samples: 432
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2552, 7)
#   - Regression targets shape: (2552, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2552, 7)
#   - X_val shape: (348, 7)
#   - X_test shape: (432, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:44.418500
# processing node 8
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:44.768742
# Start Train/Val Split: 2026-04-16 16:21:44.830447
# Start Oversampling: 2026-04-16 16:21:44.909895
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1379
# After limiting: 460 (removed 919)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                422
# 1.0                 38
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 38, Non-overloaded: 422
# Generating 384 synthetic samples for node_type 0
# Generated 384 samples for node_type 0
#
#  Total synthetic samples generated: 384
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1265, overloaded=1: 114
# Need to add 1151 more rows for overloaded=1
# Augmented rows available for this node_type=0: 384
# Repeating augmented rows 3 times
# Rows actually added: 1151
# After augmentation → overloaded=0: 1265, overloaded=1: 1265
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1265
# 1.0                1265
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1265  1265
#
# Final node_type distribution:
# node_type
# 0    2530
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 844
# Unique feature combinations for 0       : 422
# Unique feature combinations for 1       : 422
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:44.948332
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2530        347         432
# ## Data Leakage Check:
# Train Samples: 2530
# Val Samples: 347
# Test Samples: 432
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2530, 7)
#   - Regression targets shape: (2530, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2530, 7)
#   - X_val shape: (347, 7)
#   - X_test shape: (432, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:44.970284
# processing node 10
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:45.256930
# Start Train/Val Split: 2026-04-16 16:21:45.319164
# Start Oversampling: 2026-04-16 16:21:45.395682
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1378
# After limiting: 460 (removed 918)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                420
# 1.0                 40
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 40, Non-overloaded: 420
# Generating 380 synthetic samples for node_type 0
# Generated 380 samples for node_type 0
#
#  Total synthetic samples generated: 380
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1258, overloaded=1: 120
# Need to add 1138 more rows for overloaded=1
# Augmented rows available for this node_type=0: 380
# Repeating augmented rows 3 times
# Rows actually added: 1138
# After augmentation → overloaded=0: 1258, overloaded=1: 1258
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1258
# 1.0                1258
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1258  1258
#
# Final node_type distribution:
# node_type
# 0    2516
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 840
# Unique feature combinations for 0       : 420
# Unique feature combinations for 1       : 420
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:45.432732
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2516        348         432
# ## Data Leakage Check:
# Train Samples: 2516
# Val Samples: 348
# Test Samples: 432
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2516, 7)
#   - Regression targets shape: (2516, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2516, 7)
#   - X_val shape: (348, 7)
#   - X_test shape: (432, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:45.454608
# processing node 11
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:45.750491
# Start Train/Val Split: 2026-04-16 16:21:45.809960
# Start Oversampling: 2026-04-16 16:21:45.887573
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1389
# After limiting: 442 (removed 947)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                408
# 1.0                 34
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 34, Non-overloaded: 408
# Generating 374 synthetic samples for node_type 0
# Generated 374 samples for node_type 0
#
#  Total synthetic samples generated: 374
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1287, overloaded=1: 102
# Need to add 1185 more rows for overloaded=1
# Augmented rows available for this node_type=0: 374
# Repeating augmented rows 4 times
# Rows actually added: 1185
# After augmentation → overloaded=0: 1287, overloaded=1: 1287
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1287
# 1.0                1287
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1287  1287
#
# Final node_type distribution:
# node_type
# 0    2574
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 816
# Unique feature combinations for 0       : 408
# Unique feature combinations for 1       : 408
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:45.927239
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2574        340         429
# ## Data Leakage Check:
# Train Samples: 2574
# Val Samples: 340
# Test Samples: 429
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2574, 7)
#   - Regression targets shape: (2574, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2574, 7)
#   - X_val shape: (340, 7)
#   - X_test shape: (429, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:45.948349
# processing node 12
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:46.249661
# Start Train/Val Split: 2026-04-16 16:21:46.311758
# Start Oversampling: 2026-04-16 16:21:46.388742
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1378
# After limiting: 461 (removed 917)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                426
# 1.0                 35
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 35, Non-overloaded: 426
# Generating 391 synthetic samples for node_type 0
# Generated 391 samples for node_type 0
#
#  Total synthetic samples generated: 391
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1273, overloaded=1: 105
# Need to add 1168 more rows for overloaded=1
# Augmented rows available for this node_type=0: 391
# Repeating augmented rows 3 times
# Rows actually added: 1168
# After augmentation → overloaded=0: 1273, overloaded=1: 1273
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1273
# 1.0                1273
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1273  1273
#
# Final node_type distribution:
# node_type
# 0    2546
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 852
# Unique feature combinations for 0       : 426
# Unique feature combinations for 1       : 426
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:46.427219
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2546        348         432
# ## Data Leakage Check:
# Train Samples: 2546
# Val Samples: 348
# Test Samples: 432
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2546, 7)
#   - Regression targets shape: (2546, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2546, 7)
#   - X_val shape: (348, 7)
#   - X_test shape: (432, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:46.447714
# processing node 13
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:46.748532
# Start Train/Val Split: 2026-04-16 16:21:46.810116
# Start Oversampling: 2026-04-16 16:21:46.887146
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1378
# After limiting: 460 (removed 918)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                425
# 1.0                 35
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 35, Non-overloaded: 425
# Generating 390 synthetic samples for node_type 0
# Generated 390 samples for node_type 0
#
#  Total synthetic samples generated: 390
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1273, overloaded=1: 105
# Need to add 1168 more rows for overloaded=1
# Augmented rows available for this node_type=0: 390
# Repeating augmented rows 3 times
# Rows actually added: 1168
# After augmentation → overloaded=0: 1273, overloaded=1: 1273
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1273
# 1.0                1273
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1273  1273
#
# Final node_type distribution:
# node_type
# 0    2546
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 850
# Unique feature combinations for 0       : 425
# Unique feature combinations for 1       : 425
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:46.925830
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2546        348         432
# ## Data Leakage Check:
# Train Samples: 2546
# Val Samples: 348
# Test Samples: 432
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2546, 7)
#   - Regression targets shape: (2546, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2546, 7)
#   - X_val shape: (348, 7)
#   - X_test shape: (432, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:46.947049
# processing node 14
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:47.249537
# Start Train/Val Split: 2026-04-16 16:21:47.357819
# Start Oversampling: 2026-04-16 16:21:47.435585
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1378
# After limiting: 461 (removed 917)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                426
# 1.0                 35
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 35, Non-overloaded: 426
# Generating 391 synthetic samples for node_type 0
# Generated 391 samples for node_type 0
#
#  Total synthetic samples generated: 391
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1273, overloaded=1: 105
# Need to add 1168 more rows for overloaded=1
# Augmented rows available for this node_type=0: 391
# Repeating augmented rows 3 times
# Rows actually added: 1168
# After augmentation → overloaded=0: 1273, overloaded=1: 1273
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1273
# 1.0                1273
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1273  1273
#
# Final node_type distribution:
# node_type
# 0    2546
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 852
# Unique feature combinations for 0       : 426
# Unique feature combinations for 1       : 426
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:47.475880
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2546        348         432
# ## Data Leakage Check:
# Train Samples: 2546
# Val Samples: 348
# Test Samples: 432
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2546, 7)
#   - Regression targets shape: (2546, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2546, 7)
#   - X_val shape: (348, 7)
#   - X_test shape: (432, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:47.496606
# processing node 16
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:47.788054
# Start Train/Val Split: 2026-04-16 16:21:47.851948
# Start Oversampling: 2026-04-16 16:21:47.927666
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 1378
# After limiting: 460 (removed 918)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                423
# 1.0                 37
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 0] Overloaded: 37, Non-overloaded: 423
# Generating 386 synthetic samples for node_type 0
# Generated 386 samples for node_type 0
#
#  Total synthetic samples generated: 386
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(0)]
#
#
# --- Processing node_type: 0 ---
# Original counts → overloaded=0: 1267, overloaded=1: 111
# Need to add 1156 more rows for overloaded=1
# Augmented rows available for this node_type=0: 386
# Repeating augmented rows 3 times
# Rows actually added: 1156
# After augmentation → overloaded=0: 1267, overloaded=1: 1267
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                1267
# 1.0                1267
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 0                1267  1267
#
# Final node_type distribution:
# node_type
# 0    2534
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 846
# Unique feature combinations for 0       : 423
# Unique feature combinations for 1       : 423
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:47.965548
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 0          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         2534        348         432
# ## Data Leakage Check:
# Train Samples: 2534
# Val Samples: 348
# Test Samples: 432
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (2534, 7)
#   - Regression targets shape: (2534, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (2534, 7)
#   - X_val shape: (348, 7)
#   - X_test shape: (432, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:48.014447
# processing node 2
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:48.307648
# Start Train/Val Split: 2026-04-16 16:21:48.505208
# Start Oversampling: 2026-04-16 16:21:48.624016
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4558
# After limiting: 1520 (removed 3038)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1438
# 1.0                  82
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 1] Overloaded: 82, Non-overloaded: 1438
# Generating 1356 synthetic samples for node_type 1
# Generated 1356 samples for node_type 1
#
#  Total synthetic samples generated: 1356
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(1)]
#
#
# --- Processing node_type: 1 ---
# Original counts → overloaded=0: 4314, overloaded=1: 244
# Need to add 4070 more rows for overloaded=1
# Augmented rows available for this node_type=1: 1356
# Repeating augmented rows 4 times
# Rows actually added: 4070
# After augmentation → overloaded=0: 4314, overloaded=1: 4314
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                4314
# 1.0                4314
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 1                4314  4314
#
# Final node_type distribution:
# node_type
# 1    8628
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2876
# Unique feature combinations for 0       : 1438
# Unique feature combinations for 1       : 1438
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:48.726208
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 1          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         8628       1139        1425
# ## Data Leakage Check:
# Train Samples: 8628
# Val Samples: 1139
# Test Samples: 1425
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (8628, 7)
#   - Regression targets shape: (8628, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (8628, 7)
#   - X_val shape: (1139, 7)
#   - X_test shape: (1425, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:48.766342
# processing node 3
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:49.772570
# Start Train/Val Split: 2026-04-16 16:21:49.974238
# Start Oversampling: 2026-04-16 16:21:50.082503
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4557
# After limiting: 1520 (removed 3037)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1439
# 1.0                  81
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 1] Overloaded: 81, Non-overloaded: 1439
# Generating 1358 synthetic samples for node_type 1
# Generated 1358 samples for node_type 1
#
#  Total synthetic samples generated: 1358
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(1)]
#
#
# --- Processing node_type: 1 ---
# Original counts → overloaded=0: 4315, overloaded=1: 242
# Need to add 4073 more rows for overloaded=1
# Augmented rows available for this node_type=1: 1358
# Repeating augmented rows 3 times
# Rows actually added: 4073
# After augmentation → overloaded=0: 4315, overloaded=1: 4315
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                4315
# 1.0                4315
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 1                4315  4315
#
# Final node_type distribution:
# node_type
# 1    8630
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2878
# Unique feature combinations for 0       : 1439
# Unique feature combinations for 1       : 1439
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:50.183275
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 1          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         8630       1143        1422
# ## Data Leakage Check:
# Train Samples: 8630
# Val Samples: 1143
# Test Samples: 1422
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (8630, 7)
#   - Regression targets shape: (8630, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (8630, 7)
#   - X_val shape: (1143, 7)
#   - X_test shape: (1422, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:50.223474
# processing node 5
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:51.201089
# Start Train/Val Split: 2026-04-16 16:21:51.397850
# Start Oversampling: 2026-04-16 16:21:51.515993
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4559
# After limiting: 1520 (removed 3039)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1439
# 1.0                  81
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 1] Overloaded: 81, Non-overloaded: 1439
# Generating 1358 synthetic samples for node_type 1
# Generated 1358 samples for node_type 1
#
#  Total synthetic samples generated: 1358
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(1)]
#
#
# --- Processing node_type: 1 ---
# Original counts → overloaded=0: 4316, overloaded=1: 243
# Need to add 4073 more rows for overloaded=1
# Augmented rows available for this node_type=1: 1358
# Repeating augmented rows 3 times
# Rows actually added: 4073
# After augmentation → overloaded=0: 4316, overloaded=1: 4316
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                4316
# 1.0                4316
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 1                4316  4316
#
# Final node_type distribution:
# node_type
# 1    8632
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2878
# Unique feature combinations for 0       : 1439
# Unique feature combinations for 1       : 1439
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:51.617085
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 1          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         8632       1140        1423
# ## Data Leakage Check:
# Train Samples: 8632
# Val Samples: 1140
# Test Samples: 1423
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (8632, 7)
#   - Regression targets shape: (8632, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (8632, 7)
#   - X_val shape: (1140, 7)
#   - X_test shape: (1423, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:51.657691
# processing node 6
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:52.699169
# Start Train/Val Split: 2026-04-16 16:21:52.894575
# Start Oversampling: 2026-04-16 16:21:53.013666
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4557
# After limiting: 1520 (removed 3037)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1438
# 1.0                  82
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 1] Overloaded: 82, Non-overloaded: 1438
# Generating 1356 synthetic samples for node_type 1
# Generated 1356 samples for node_type 1
#
#  Total synthetic samples generated: 1356
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(1)]
#
#
# --- Processing node_type: 1 ---
# Original counts → overloaded=0: 4313, overloaded=1: 244
# Need to add 4069 more rows for overloaded=1
# Augmented rows available for this node_type=1: 1356
# Repeating augmented rows 4 times
# Rows actually added: 4069
# After augmentation → overloaded=0: 4313, overloaded=1: 4313
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                4313
# 1.0                4313
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 1                4313  4313
#
# Final node_type distribution:
# node_type
# 1    8626
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2876
# Unique feature combinations for 0       : 1438
# Unique feature combinations for 1       : 1438
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:53.114217
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 1          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         8626       1140        1425
# ## Data Leakage Check:
# Train Samples: 8626
# Val Samples: 1140
# Test Samples: 1425
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (8626, 7)
#   - Regression targets shape: (8626, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (8626, 7)
#   - X_val shape: (1140, 7)
#   - X_test shape: (1425, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:53.154636
# processing node 7
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:54.133849
# Start Train/Val Split: 2026-04-16 16:21:54.332642
# Start Oversampling: 2026-04-16 16:21:54.452957
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4558
# After limiting: 1513 (removed 3045)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1427
# 1.0                  86
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 1] Overloaded: 86, Non-overloaded: 1427
# Generating 1341 synthetic samples for node_type 1
# Generated 1341 samples for node_type 1
#
#  Total synthetic samples generated: 1341
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(1)]
#
#
# --- Processing node_type: 1 ---
# Original counts → overloaded=0: 4302, overloaded=1: 256
# Need to add 4046 more rows for overloaded=1
# Augmented rows available for this node_type=1: 1341
# Repeating augmented rows 4 times
# Rows actually added: 4046
# After augmentation → overloaded=0: 4302, overloaded=1: 4302
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                4302
# 1.0                4302
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 1                4302  4302
#
# Final node_type distribution:
# node_type
# 1    8604
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2854
# Unique feature combinations for 0       : 1427
# Unique feature combinations for 1       : 1427
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:54.554257
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 1          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         8604       1141        1423
# ## Data Leakage Check:
# Train Samples: 8604
# Val Samples: 1141
# Test Samples: 1423
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (8604, 7)
#   - Regression targets shape: (8604, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (8604, 7)
#   - X_val shape: (1141, 7)
#   - X_test shape: (1423, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:54.595047
# processing node 9
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:55.592042
# Start Train/Val Split: 2026-04-16 16:21:55.790819
# Start Oversampling: 2026-04-16 16:21:55.910839
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4558
# After limiting: 1522 (removed 3036)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1440
# 1.0                  82
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 1] Overloaded: 82, Non-overloaded: 1440
# Generating 1358 synthetic samples for node_type 1
# Generated 1358 samples for node_type 1
#
#  Total synthetic samples generated: 1358
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(1)]
#
#
# --- Processing node_type: 1 ---
# Original counts → overloaded=0: 4318, overloaded=1: 240
# Need to add 4078 more rows for overloaded=1
# Augmented rows available for this node_type=1: 1358
# Repeating augmented rows 4 times
# Rows actually added: 4078
# After augmentation → overloaded=0: 4318, overloaded=1: 4318
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                4318
# 1.0                4318
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 1                4318  4318
#
# Final node_type distribution:
# node_type
# 1    8636
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2880
# Unique feature combinations for 0       : 1440
# Unique feature combinations for 1       : 1440
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:56.013270
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 1          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         8636       1139        1425
# ## Data Leakage Check:
# Train Samples: 8636
# Val Samples: 1139
# Test Samples: 1425
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (8636, 7)
#   - Regression targets shape: (8636, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (8636, 7)
#   - X_val shape: (1139, 7)
#   - X_test shape: (1425, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:56.053813
# processing node 17
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:57.049249
# Start Train/Val Split: 2026-04-16 16:21:57.247226
# Start Oversampling: 2026-04-16 16:21:57.366397
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4554
# After limiting: 1519 (removed 3035)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1438
# 1.0                  81
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 1] Overloaded: 81, Non-overloaded: 1438
# Generating 1357 synthetic samples for node_type 1
# Generated 1357 samples for node_type 1
#
#  Total synthetic samples generated: 1357
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(1)]
#
#
# --- Processing node_type: 1 ---
# Original counts → overloaded=0: 4313, overloaded=1: 241
# Need to add 4072 more rows for overloaded=1
# Augmented rows available for this node_type=1: 1357
# Repeating augmented rows 4 times
# Rows actually added: 4072
# After augmentation → overloaded=0: 4313, overloaded=1: 4313
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                4313
# 1.0                4313
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 1                4313  4313
#
# Final node_type distribution:
# node_type
# 1    8626
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2876
# Unique feature combinations for 0       : 1438
# Unique feature combinations for 1       : 1438
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:57.468993
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 1          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         8626       1138        1430
# ## Data Leakage Check:
# Train Samples: 8626
# Val Samples: 1138
# Test Samples: 1430
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (8626, 7)
#   - Regression targets shape: (8626, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (8626, 7)
#   - X_val shape: (1138, 7)
#   - X_test shape: (1430, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:57.510264
# processing node 19
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:21:58.543026
# Start Train/Val Split: 2026-04-16 16:21:58.741640
# Start Oversampling: 2026-04-16 16:21:58.861019
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4547
# After limiting: 1510 (removed 3037)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1432
# 1.0                  78
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 1] Overloaded: 78, Non-overloaded: 1432
# Generating 1354 synthetic samples for node_type 1
# Generated 1354 samples for node_type 1
#
#  Total synthetic samples generated: 1354
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(1)]
#
#
# --- Processing node_type: 1 ---
# Original counts → overloaded=0: 4313, overloaded=1: 234
# Need to add 4079 more rows for overloaded=1
# Augmented rows available for this node_type=1: 1354
# Repeating augmented rows 4 times
# Rows actually added: 4079
# After augmentation → overloaded=0: 4313, overloaded=1: 4313
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                4313
# 1.0                4313
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 1                4313  4313
#
# Final node_type distribution:
# node_type
# 1    8626
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2864
# Unique feature combinations for 0       : 1432
# Unique feature combinations for 1       : 1432
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:21:58.964045
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 1          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         8626       1152        1423
# ## Data Leakage Check:
# Train Samples: 8626
# Val Samples: 1152
# Test Samples: 1423
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (8626, 7)
#   - Regression targets shape: (8626, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (8626, 7)
#   - X_val shape: (1152, 7)
#   - X_test shape: (1423, 7)
#
# Transforming for Janoosy: 2026-04-16 16:21:59.004882
# processing node 1
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:22:00.003094
# Start Train/Val Split: 2026-04-16 16:22:00.200450
# Start Oversampling: 2026-04-16 16:22:00.318261
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4765
# After limiting: 1496 (removed 3269)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1139
# 1.0                 357
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 2] Overloaded: 357, Non-overloaded: 1139
# Generating 782 synthetic samples for node_type 2
# Generated 782 samples for node_type 2
#
#  Total synthetic samples generated: 782
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(2)]
#
#
# --- Processing node_type: 2 ---
# Original counts → overloaded=0: 3691, overloaded=1: 1074
# Need to add 2617 more rows for overloaded=1
# Augmented rows available for this node_type=2: 782
# Repeating augmented rows 4 times
# Rows actually added: 2617
# After augmentation → overloaded=0: 3691, overloaded=1: 3691
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                3691
# 1.0                3691
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 2                3691  3691
#
# Final node_type distribution:
# node_type
# 2    7382
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2278
# Unique feature combinations for 0       : 1139
# Unique feature combinations for 1       : 1139
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:22:00.412957
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 2          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         7382       1194        1482
# ## Data Leakage Check:
# Train Samples: 7382
# Val Samples: 1194
# Test Samples: 1482
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (7382, 7)
#   - Regression targets shape: (7382, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (7382, 7)
#   - X_val shape: (1194, 7)
#   - X_test shape: (1482, 7)
#
# Transforming for Janoosy: 2026-04-16 16:22:00.451088
# processing node 15
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:22:01.348035
# Start Train/Val Split: 2026-04-16 16:22:01.551218
# Start Oversampling: 2026-04-16 16:22:01.659780
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4774
# After limiting: 1543 (removed 3231)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1204
# 1.0                 339
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 2] Overloaded: 339, Non-overloaded: 1204
# Generating 865 synthetic samples for node_type 2
# Generated 865 samples for node_type 2
#
#  Total synthetic samples generated: 865
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(2)]
#
#
# --- Processing node_type: 2 ---
# Original counts → overloaded=0: 3700, overloaded=1: 1074
# Need to add 2626 more rows for overloaded=1
# Augmented rows available for this node_type=2: 865
# Repeating augmented rows 4 times
# Rows actually added: 2626
# After augmentation → overloaded=0: 3700, overloaded=1: 3700
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                3700
# 1.0                3700
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 2                3700  3700
#
# Final node_type distribution:
# node_type
# 2    7400
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2408
# Unique feature combinations for 0       : 1204
# Unique feature combinations for 1       : 1204
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:22:01.758576
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 2          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         7400       1201        1466
# ## Data Leakage Check:
# Train Samples: 7400
# Val Samples: 1201
# Test Samples: 1466
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (7400, 7)
#   - Regression targets shape: (7400, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (7400, 7)
#   - X_val shape: (1201, 7)
#   - X_test shape: (1466, 7)
#
# Transforming for Janoosy: 2026-04-16 16:22:01.797783
# processing node 18
# # Task: Multi_Task
# ---
# Start CV Split (single fold only): 2026-04-16 16:22:02.699594
# Start Train/Val Split: 2026-04-16 16:22:02.887341
# Start Oversampling: 2026-04-16 16:22:03.001236
# ## Oversampling
# === Limiting to max 1 identical combinations ===
# Original row count: 4736
# After limiting: 1443 (removed 3293)
#
# Class distribution after limiting:
# overloaded_node
# 0.0                1089
# 1.0                 354
# Name: count, dtype: int64
#
# === Generating synthetic overloaded samples (Unique Features Balancing) ===
#
# [Node Type 2] Overloaded: 354, Non-overloaded: 1089
# Generating 735 synthetic samples for node_type 2
# Generated 735 samples for node_type 2
#
#  Total synthetic samples generated: 735
# Augmented rows saved to 'augmented_overloaded_samples.csv'
#
# ========= ROWS BALANCING =========
#
# Node types found: [np.int64(2)]
#
#
# --- Processing node_type: 2 ---
# Original counts → overloaded=0: 3653, overloaded=1: 1083
# Need to add 2570 more rows for overloaded=1
# Augmented rows available for this node_type=2: 735
# Repeating augmented rows 4 times
# Rows actually added: 2570
# After augmentation → overloaded=0: 3653, overloaded=1: 3653
#
# ========= BALANCING COMPLETED =========
#
#
# Final class distribution after rebalancing:
# overloaded_node
# 0.0                3653
# 1.0                3653
# Name: count, dtype: int64
#
# Final class distribution after rebalancing (node_type-wise):
# overloaded_node   0.0   1.0
# node_type
# 2                3653  3653
#
# Final node_type distribution:
# node_type
# 2    7306
# Name: count, dtype: int64
#
# ========= FINAL UNIQUE FEATURES SUMMARY =========
# Total unique feature combinations       : 2178
# Unique feature combinations for 0       : 1089
# Unique feature combinations for 1       : 1089
# ==========================================
#
# Start Preprocessing: 2026-04-16 16:22:03.096108
# ## Preprocessing
# # Multi_Task
# ---
# ## Node Type Distribution Across Splits:
#            Train    Val   Test
# node_type
# 2          100.0  100.0  100.0
#
#  Dataset Sizes:
#             Train Total  Val Total  Test Total
# Total Rows         7306       1203        1502
# ## Data Leakage Check:
# Train Samples: 7306
# Val Samples: 1203
# Test Samples: 1502
#
#
# No data leakage detected. Splits are clean.
# ## Scalaing
# [INFO] MinMaxScaler fitted:
#   - Features shape: (7306, 7)
#   - Regression targets shape: (7306, 22)
#   - Classification column '['overloaded_node']' excluded from scaling
#
# [INFO] Scalers saved for target 'Multi_Task'
#
# [INFO] Transformation complete.
#   - X_train shape: (7306, 7)
#   - X_val shape: (1203, 7)
#   - X_test shape: (1502, 7)
#
# Transforming for Janoosy: 2026-04-16 16:22:03.134495
# ...done
# '../experiments/20n-19k/seed4850/0'
